# %% [markdown]
# # Homework 2

# %% [markdown]
# ##  1. Given the following implementation of the class `PriorityQueue`, implement the methods:
#
# - `insert(v,k)` - add an element $v$ with priority $k$. Complexity $O(n)$
# - `deleteMin()` - remove the element with the lowest $k$ (highest priority). Complexity $O(1)$
# - `decreaseKey(v,k)` - decrease the value of $k$ (increase priority). Complexity $O(n)$
#
# **Show complexity analysis for each implementation**

# %% [markdown]
# ## base implementations

# %%
import ctypes
class PriorityQueue(object):
    """
    Implementation of the queue data structure
    """

    def __init__(self, n):
        self.item_count = 0
        self.n = n
        self.queue = self._create_queue(self.n)        
    
    def _create_queue(self, n):
        """
        Creates a new stack of capacity n
        """
        return (n * ctypes.py_object)()
    
    def enqueue(self, item):
        """
        Add new item to the queue
        """
        if self.item_count == self.n:
            raise ValueError("no more capacity")
        
        for i in range(0,self.item_count+1):
            self.queue[i+1] = self.queue[i]
        self.queue[0] = item
        self.item_count += 1
        
 #Homework implementatios:
    def insert (self, v, k):
        val = ((k,v))
        self.enqueue(val)
        self.sort()
    
    def sort(self):
        self.queue = sorted(self.queue, reverse = True)
        
    def deleteMin (self):
        c = self.queue[self.item_count]
        self.queue[self.item_count] = None
        return c
    
    def decreseKey (self, v , k):
        
        for i in range(0,self.item_count):
            if self.queue[i][1] == v:
                self.queue[i] = ((k,v))
                return
        raise ValueError ("Value v not found")

# %% [markdown]
# ## 2. class Node:
#     """
#     Implementation of a node
#     """
#     def __init__(self, val=None):
#         self.val = val
#         self.next_node = None
#
#     def set_next_node(self, next_node):
#         self.next_node = next_node
#
# class Singly_linked_list:
#     """
#     Implementation of a singly linked list
#     """
#     def __init__(self, head_node=None):
#         self.head_node = head_node
#
# For example:
#
# **Input:**
# - $L_1$ = 1 -> 4 -> 5
# - $L_2$ = 4 -> 3 -> 2
#
# **Output:**
# - $L_3$ = 5 -> 7 -> 7
#
# Note that, the problem is equivalent to adding: 541 + 234  =  775

# %%
class Node:
    """
    Implementation of a node
    """
    def __init__(self, val=None):
        self.val = val
        self.next_node = None
    
    def set_next_node(self, next_node):
        self.next_node = next_node
        
class Singly_linked_list:
    """
    Implementation of a singly linked list
    """
    def __init__(self, head_node=None):
        self.head_node = head_node

# %%
def linked_sum(A,B):
    """
    A, B son mis linked lists correspondientes a L1 y L2
    """
    #esta sera la cabeza de la lista respuesta
    C = Node(0)
    F = Singly_linked_list(C)
    
    extra = 0
    while (A.next_node != None or B.next_node != None):
        x = ((A.next_node != None) * A.val) or 0
        y = ((B.next_node != None) * B.val) or 0
        
        suma = extra + x + y
        extra = suma/10
        
        C.val = suma % 10
        C.set_next_node(Node(0))
        C = C.next_node
        
        A = A.next_node
        B = B.next_node
        
    if extra > 0:
        C.set_next_node(Node(extra))
        
    return F

# %% [markdown]
# ## 3. Given a linked list, detect if the list has a cycle. If a cycle is detected, return the position of the node (with respect to the head) where the cycle starts.
#
# For example:
#
# ![](./cycle.png)
#
# **Input:**
# - Jan -> Feb -> March -> Dec
#
# **Output:**
# - True
# - 2

# %%
class Node:
    """
    Implementation of a node
    """
    def __init__(self, val=None):
        self.val = val
        self.next_node = None
        """
        implementamos un flag de visita
        """
        self.flag = False
    
    def set_next_node(self, next_node):
        self.next_node = next_node
        
class Singly_linked_list:
    """
    Implementation of a singly linked list
    """
    def __init__(self, head_node=None):
        self.head_node = head_node
        
    def loop(self, node):
        pos = 0
        while node != None:
            if node.flag == True:
                return True, pos
            else:
                node.flag = True
                node = node.next_node
                pos += 1
                
        return False

# %% [markdown]
# ## 4.  CLRS 10.1-5
# pg. 236
#
# **Implement as a Python class**

# %%
import ctypes
class deque(object):
    """
    (Dequeue?) implementation
    """
    
    """
    implementando usando built-in lists, also asume que tail es en posicion 0
    """

    def __init__ (self):
        self.items = []
        
    def empty (self):
        return self.items == []
    
    def head_enqueue (self, item):
        self.items.append(item)
        
    def head_dequeue (self):
        return self.items.pop()
    
    def tail_enqueue(self,item):
        self.items.insert(0,item)
        
    def tail_dequeu (self):
        self.items.pop(0)
        
    def size (self):
        return len(self.items)

# %% [markdown]
# ## 5.  CLRS 10.1-6
# pg. 236
#
# **Implement as a Python class**

# %%
class Stack(object):
    """
    Implementation of the stack data structure
    """

    def __init__(self, n):
        self.item_count = 0
        self.n = n
        self.stack = self._create_stack(self.n)        
    
    def _create_stack(self, n):
        """
        Creates a new stack of capacity n
        """
        return (n * ctypes.py_object)()
    
    def push(self, item):
        """
        Add new item to the stack
        """
        if self.item_count == self.n:
            raise ValueError("no more capacity")
        self.stack[self.item_count] = item
        self.item_count += 1
        
    def pop(self):
        """
        Remove an element from the stack
        """
        c = self.stack[self.item_count-1]
        self.stack[self.item_count] = ctypes.py_object
        self.item_count -= 1
        return c
        
    def top(self):
        """
        Show the top element of the stack
        """
        return self.stack[self.item_count-1]

    def full(self):
        """
        Is the stack full?
        """
        if self.item_count == self.n:
            return True
        return False

    def empty(self):
        """
        Is the stack empty?
        """
        if self.item_count == 0:
            return True
        return False

    def size(self):
        """
        Return size of the stack
        """
        return self.item_count

# %%
A = Stack(10)
B = Stack(10)

# %%
import ctypes

class stack_queue(object):
    
    def __init__ (self, n, A, B):
        self.item_count = 0
        self.n = n
        self.queue = self._create_stack_queue(self.n)
        self.A = A
        self.B = B
        
    def _create_stack_queue(self,n):
        return (n*ctypes.py_object)()
    
    def enqueue (self, item):
        B.push(item)
        
    def dequeue (self):
        if A.empty:
            while B.empty == True:
                A.push(B.pop())
            return A.pop()
        else:
            return A.pop()

# %%
C = stack_queue(10,A,B)

# %% [markdown]
# ENQUEUE tiene un tiempo de corrido de $O(1)$, mientras que el peor caso de DEQUEUE tiene un tiempo de corrido de $O(n)$

# %% [markdown]
# ## 6.  CLRS 10.1-7
# pg. 236
#
# **Implement as a Python class**

# %%
import ctypes
class Queue(object):
    """
    Implementation of the queue data structure
    """

    def __init__(self, n):
        self.item_count = 0
        self.n = n
        self.queue = self._create_queue(self.n)        
    
    def _create_queue(self, n):
        """
        Creates a new stack of capacity n
        """
        return (n * ctypes.py_object)()
    
    def enqueue(self, item):
        """
        Add new item to the queue
        """
        if self.item_count == self.n:
            raise ValueError("no more capacity")
        self.queue[self.item_count] = item
        self.item_count += 1

    # O(n)
    def dequeue(self):
        """
        Remove an element from the queue
        """
        c = self.queue[0]
        for i in range(1,self.item_count):
            self.queue[i-1] = self.queue[i]
        self.queue[self.item_count - 1] = ctypes.py_object
        self.item_count -= 1
        return c
    
    # O(1)
    def first(self):
        """
        Show the first element of the queue
        """
        return self.queue[0]
    
    # O(1)
    def full(self):
        """
        Is the queue full?
        """
        if self.item_count == self.n:
            return True
        return False

    def empty(self):
        """
        Is the queue empty?
        """
        if self.item_count == 0:
            return True
        return False

    def size(self):
        """
        Return size of the stack
        """
        return self.item_count

# %%
def queue_stack(object):
    
    def __init__ (self, n , A, B):
        self.item_count = 0
        self.n = n
        self.activeQ = A
        self.inactiveQ = B
        self.stack = self._create_queue_stack(self.n)
        
    def _create_queue_stack(self,n):
        return (n * ctypes.py_object)()
    
    def push (self, item):
        self.activeQ.enqueue(item)
        
    def pop (self):
        for i in range(0,self.item_count - 1):
            self.inactiveQ.enqueue(self.activeQ.dequeue)
            
        self.activeQ,self.inactiveQ = A,B
        return self.inactiveQ.dequeue

# %% [markdown]
# PUSH tiene un tiempo de $O(1)$ y POP siempre tendra un tiempo de $O(n)$ donde $n$ es el numero de elementos en el QEUEUE_STACK
