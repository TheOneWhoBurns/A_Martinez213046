# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class Node:
    """
    Implementation of a node
    """
    def __init__(self, val=None):
        self.val = val
        self.next_node = None
        self.prev_node = None
        
class Doubly_linked_list:
    """
    Implementation of a singly linked list
    """
    def __init__(self, head_node=None):
        self.head_node = head_node
        
    def list_traversed(self):
        node = self.head_node
        while node:
            print(node.val)
            node = node.next_node
    
    def deleteHead (self):
        self.head_node.next_node.prev_node = None
        self.head_node = self.head_node.next_node
    
    def deleteTail (self): 
        node = self.head_node
        while node:
            node = node.next_node
        
        node.prev_node.next_node = None
        
    def delete (self, node):
        n = self.head_node
        while n:
            if n == node:
                break
            n = node.next_node
        if not n:
            raise ValueError("node not found")
            
        node.next_node.prev_node = node.prev_node
        node.prev_node.next_node = node.next_node
        node.next_node = None
        node.prev_node = None
        
    def reverseList (self):
        node =  self.head_node
        
        while node:
            
            node.prev_node,node.next_node = node.next_node,node.prev_node
            node = node.prev_node
        
        self.head_node = node

# %% [raw]
# A -> B -> C -> D
#
# **Magic of Computer**
#
# A <- B <- C <- D

# %%
class Node:
    """
    Implementation of a node
    """
    def __init__(self, val=None):
        self.val = val
        self.next_node = None
    
    def set_next_node(self, next_node):
        self.next_node = next_node
        
class Singly_linked_list:
    """
    Implementation of a singly linked list
    """
    def __init__(self, head_node=None):
        self.head_node = head_node
        
    def revereseList (self):
        prev = None
        actual = self.head_node
        while actual:
            next = actual.next_node
            actual.next = prev
            prev = actual
            current = next
        self.head_node = prev
