# %%
class limitStack:
    
    def __init__ (self):
        self.list = []
        self.stack_size = 10
        
    def newStack(self):
        return Stack(self.stack_size)
    
    def add(self,item):
        if self.list[-1].full() or len(self.list) == 0:
            S = newStack()
            self.list.append(S)
            self.list[-1].push(item)
        else:
            self.list[-1].push(item)
            
    def pop(self):
        if len(self.list) == 0:
            return None
        elif self.list[-1].empty():
            
            del self.list[-1]
            if len(self.list) == 0:
                return None
            else:
                self.list[-1].pop()
                
        else:
                self.list[-1].pop()
    
    def top(self):
        if len(self.list) == 0:
            return None
        elif self.list[-1].empty():
            del self.list[-1]
            if len(self.list) == 0:
                return None
            else:
                self.list[-1].top()
                
        else:
                self.list[-1].top()

# %%
def list_sum(A,B):
    def n_to_l(N):
        
        head = None
        newNode = None
        
        for i in str(N):
            
            node = Node(i)
            
            if head is None:
                head = node
                newNode = node
            else:
                newNode.set_next_node(node)
    return head
    
    Alist = n_to_l(A)
    Blist = n_to_l(B)
    
    def reverse(L):
        prev = None
        current = L.head
        while(current is not None):
            next = current.next
            current.next = prev
            prev = current
            current = next
        L.head = prev
        
    Alist = reverse(Alist)
    Blist = reverse(Blist)
    
    C = Node(None)
    D = Singly_linked_list(C)
    while (Alist.next != None or Blist.next != None ):
        
        C.val = (A.next * A.val or 0) - (B.next * B.val or 0)
        
        C.set_next_node = Node(None)
        C = C.next
        A = A.next
        B = B.next
        
    
    return D

# %%
def red_nodes(root):
    global reds = 0
    
    def traversal(root):

        if root
            if isRed(root):
                reds += 1
            traversal(root.left)
            traversal(root.right)

        return
    return reds
    
def isRed(node):
    red = True
    value = node.val
    if node is None:
        return False
    
    else:
        while (node >= 1):
            if node > value:
                red = False
                break
            node //= 2
        return red
